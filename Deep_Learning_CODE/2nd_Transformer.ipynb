# %%
# !pip install optuna --quiet

# %%
# 나눔고딕 폰트 설치 및 설정
# !apt-get update -qq
# !apt-get install fonts-nanum -qq
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt

# 폰트 설정
import matplotlib.font_manager as fm

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 📦 라이브러리 로드
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, f1_score, roc_curve, auc
import optuna
import warnings
warnings.filterwarnings("ignore")

# 📌 데이터 로드 및 전처리
df = pd.read_csv('/content/employee_new3.csv')
df = df[df['Gender'] != 'Other']
df['Resigned'] = df['Resigned'].astype(int)
for col in df.select_dtypes(include='object').columns:
    df[col] = LabelEncoder().fit_transform(df[col])

X = df.drop(columns=['Resigned', 'Employee_ID', 'Hire_Date'], errors='ignore')
y = df['Resigned']

# 클래스 균형 맞춤 (10,000씩)
X_0 = X[y == 0].sample(n=10000, random_state=42)
y_0 = y[y == 0].sample(n=10000, random_state=42)
X_1 = X[y == 1]
y_1 = y[y == 1]
repeat_count = 10000 // len(X_1) + 1
X_1_sampled = pd.concat([X_1] * repeat_count)[:10000].reset_index(drop=True)
y_1_sampled = pd.concat([y_1] * repeat_count)[:10000].reset_index(drop=True)
X_balanced = pd.concat([X_0, X_1_sampled]).reset_index(drop=True)
y_balanced = pd.concat([y_0, y_1_sampled]).reset_index(drop=True)

# 결측값 처리 및 스케일링
X_balanced = X_balanced.fillna(X_balanced.mean(numeric_only=True))
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_balanced)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_balanced, test_size=0.2, stratify=y_balanced, random_state=42)

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)

# 🧠 Transformer 모델
class TabularTransformer(nn.Module):
    def __init__(self, input_dim, d_model, nhead, num_layers, dropout):
        super().__init__()
        self.input_fc = nn.Linear(input_dim, d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dropout=dropout, batch_first=True)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.output = nn.Sequential(
            nn.Linear(d_model, 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        x = self.input_fc(x).unsqueeze(1)
        x = self.transformer(x)
        x = x.squeeze(1)
        return self.output(x)

# ⏹️ EarlyStopping 클래스
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# 🔁 학습 함수
def train(model, loader, lr, epochs, val_data=None, use_earlystop=True):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()
    early_stopping = EarlyStopping(patience=5, min_delta=0.001) if use_earlystop else None

    for epoch in range(epochs):
        model.train()
        for xb, yb in loader:
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()

        if use_earlystop and val_data is not None:
            model.eval()
            with torch.no_grad():
                val_x, val_y = val_data
                val_pred = model(val_x)
                val_loss = criterion(val_pred, val_y).item()
                print(f"📉 Epoch {epoch+1}: Validation Loss = {val_loss:.4f}")
                early_stopping(val_loss)
                if early_stopping.early_stop:
                    print("⛔ Early stopping triggered!")
                    break

    model.eval()
    with torch.no_grad():
        probs = torch.sigmoid(model(X_test_tensor)).numpy().flatten()
    return probs

# 📊 평가 함수
def evaluate(y_true, probs):
    best_f1, best_th = 0, 0.5
    for th in np.arange(0.1, 0.9, 0.01):
        pred = (probs >= th).astype(int)
        f1_0 = f1_score(y_true, pred, pos_label=0)
        f1_1 = f1_score(y_true, pred, pos_label=1)
        avg = (f1_0 + f1_1) / 2
        if avg > best_f1:
            best_f1 = avg
            best_th = th
    final_pred = (probs >= best_th).astype(int)
    report = classification_report(y_true, final_pred, output_dict=True)
    return best_f1, best_th, report, final_pred

# 🎯 Optuna objective
def objective(trial):
    d_model = trial.suggest_categorical("d_model", [32, 64, 128])
    nhead = trial.suggest_categorical("nhead", [2, 4, 8])
    num_layers = trial.suggest_int("num_layers", 1, 3)
    dropout = trial.suggest_float("dropout", 0.2, 0.5)
    lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical("batch_size", [128, 256, 512])
    epochs = 30

    model = TabularTransformer(X_train.shape[1], d_model, nhead, num_layers, dropout)
    full_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_size = int(0.1 * len(full_dataset))
    train_size = len(full_dataset) - val_size
    train_ds, val_ds = random_split(full_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_x, val_y = val_ds[:][0], val_ds[:][1]

    probs = train(model, train_loader, lr, epochs, val_data=(val_x, val_y), use_earlystop=True)
    f1, _, _, _ = evaluate(y_test, probs)
    return f1

# 🔍 Optuna 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=10)

# ✅ 최적 모델로 재학습 및 평가
best_params = study.best_params
print("🔧 Best Transformer Params:", best_params)

best_model = TabularTransformer(
    input_dim=X_train.shape[1],
    d_model=best_params['d_model'],
    nhead=best_params['nhead'],
    num_layers=best_params['num_layers'],
    dropout=best_params['dropout']
)

full_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_size = int(0.1 * len(full_dataset))
train_size = len(full_dataset) - val_size
train_ds, val_ds = random_split(full_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))
train_loader = DataLoader(train_ds, batch_size=best_params['batch_size'], shuffle=True)
val_x, val_y = val_ds[:][0], val_ds[:][1]

probs = train(best_model, train_loader, best_params['lr'], epochs=30, val_data=(val_x, val_y), use_earlystop=True)
f1, best_th, report, preds = evaluate(y_test, probs)

print(f"\n📊 최종 F1 Score: {f1:.4f} (Best Threshold = {best_th})")
print(classification_report(y_test, preds, target_names=["재직자(0)", "퇴사자(1)"]))

# 📈 ROC Curve
fpr, tpr, _ = roc_curve(y_test, probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("📈 ROC Curve - Transformer (with EarlyStopping & Tuning)")
plt.legend()
plt.grid()
plt.show()
# Out:
# [I 2025-08-05 08:44:16,624] A new study created in memory with name: no-name-a7915810-bef7-4835-88e3-28d5075dd3ea
# 📉 Epoch 1: Validation Loss = 0.6468
# 📉 Epoch 2: Validation Loss = 0.6442
# 📉 Epoch 3: Validation Loss = 0.6417
# 📉 Epoch 4: Validation Loss = 0.6346
# 📉 Epoch 5: Validation Loss = 0.6253
# 📉 Epoch 6: Validation Loss = 0.6183
# 📉 Epoch 7: Validation Loss = 0.6137
# 📉 Epoch 8: Validation Loss = 0.6063
# 📉 Epoch 9: Validation Loss = 0.6067
# 📉 Epoch 10: Validation Loss = 0.6032
# 📉 Epoch 11: Validation Loss = 0.5987
# 📉 Epoch 12: Validation Loss = 0.5937
# 📉 Epoch 13: Validation Loss = 0.5875
# 📉 Epoch 14: Validation Loss = 0.5830
# 📉 Epoch 15: Validation Loss = 0.5829
# 📉 Epoch 16: Validation Loss = 0.5767
# 📉 Epoch 17: Validation Loss = 0.5785
# 📉 Epoch 18: Validation Loss = 0.5870
# 📉 Epoch 19: Validation Loss = 0.5758
# 📉 Epoch 20: Validation Loss = 0.5884
# 📉 Epoch 21: Validation Loss = 0.5685
# 📉 Epoch 22: Validation Loss = 0.5697
# 📉 Epoch 23: Validation Loss = 0.5710
# 📉 Epoch 24: Validation Loss = 0.5771
# 📉 Epoch 25: Validation Loss = 0.5684
# 📉 Epoch 26: Validation Loss = 0.5654
# 📉 Epoch 27: Validation Loss = 0.5801
# 📉 Epoch 28: Validation Loss = 0.5648
# 📉 Epoch 29: Validation Loss = 0.5614
# 📉 Epoch 30: Validation Loss = 0.5617
# [I 2025-08-05 08:45:25,289] Trial 0 finished with value: 0.6473820886700746 and parameters: {'d_model': 128, 'nhead': 2, 'num_layers': 1, 'dropout': 0.2198398392066807, 'lr': 0.00037077799248048303, 'batch_size': 512}. Best is trial 0 with value: 0.6473820886700746.
# 📉 Epoch 1: Validation Loss = 0.6475
# 📉 Epoch 2: Validation Loss = 0.6368
# 📉 Epoch 3: Validation Loss = 0.6231
# 📉 Epoch 4: Validation Loss = 0.6221
# 📉 Epoch 5: Validation Loss = 0.6258
# 📉 Epoch 6: Validation Loss = 0.6104
# 📉 Epoch 7: Validation Loss = 0.5987
# 📉 Epoch 8: Validation Loss = 0.6063
# 📉 Epoch 9: Validation Loss = 0.5868
# 📉 Epoch 10: Validation Loss = 0.5921
# 📉 Epoch 11: Validation Loss = 0.6025
# 📉 Epoch 12: Validation Loss = 0.5795
# 📉 Epoch 13: Validation Loss = 0.5868
# 📉 Epoch 14: Validation Loss = 0.5708
# 📉 Epoch 15: Validation Loss = 0.5819
# 📉 Epoch 16: Validation Loss = 0.5577
# 📉 Epoch 17: Validation Loss = 0.5501
# 📉 Epoch 18: Validation Loss = 0.5643
# 📉 Epoch 19: Validation Loss = 0.5668
# 📉 Epoch 20: Validation Loss = 0.5602
# 📉 Epoch 21: Validation Loss = 0.5497
# 📉 Epoch 22: Validation Loss = 0.5416
# 📉 Epoch 23: Validation Loss = 0.5572
# 📉 Epoch 24: Validation Loss = 0.5717
# 📉 Epoch 25: Validation Loss = 0.5381
# 📉 Epoch 26: Validation Loss = 0.5361
# 📉 Epoch 27: Validation Loss = 0.5542
# 📉 Epoch 28: Validation Loss = 0.5399
# 📉 Epoch 29: Validation Loss = 0.5612
# 📉 Epoch 30: Validation Loss = 0.5501
# [I 2025-08-05 08:46:12,044] Trial 1 finished with value: 0.6483240256123984 and parameters: {'d_model': 32, 'nhead': 2, 'num_layers': 1, 'dropout': 0.24372847923584276, 'lr': 0.002500389542492971, 'batch_size': 128}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6545
# 📉 Epoch 2: Validation Loss = 0.6492
# 📉 Epoch 3: Validation Loss = 0.6480
# 📉 Epoch 4: Validation Loss = 0.6409
# 📉 Epoch 5: Validation Loss = 0.6314
# 📉 Epoch 6: Validation Loss = 0.6401
# 📉 Epoch 7: Validation Loss = 0.6379
# 📉 Epoch 8: Validation Loss = 0.6223
# 📉 Epoch 9: Validation Loss = 0.6201
# 📉 Epoch 10: Validation Loss = 0.6140
# 📉 Epoch 11: Validation Loss = 0.6231
# 📉 Epoch 12: Validation Loss = 0.6078
# 📉 Epoch 13: Validation Loss = 0.6101
# 📉 Epoch 14: Validation Loss = 0.6157
# 📉 Epoch 15: Validation Loss = 0.6048
# 📉 Epoch 16: Validation Loss = 0.6058
# 📉 Epoch 17: Validation Loss = 0.6048
# 📉 Epoch 18: Validation Loss = 0.6224
# 📉 Epoch 19: Validation Loss = 0.6030
# 📉 Epoch 20: Validation Loss = 0.6037
# 📉 Epoch 21: Validation Loss = 0.6036
# 📉 Epoch 22: Validation Loss = 0.6001
# 📉 Epoch 23: Validation Loss = 0.5953
# 📉 Epoch 24: Validation Loss = 0.6035
# 📉 Epoch 25: Validation Loss = 0.6147
# 📉 Epoch 26: Validation Loss = 0.5948
# 📉 Epoch 27: Validation Loss = 0.5928
# 📉 Epoch 28: Validation Loss = 0.5990
# 📉 Epoch 29: Validation Loss = 0.5907
# 📉 Epoch 30: Validation Loss = 0.5868
# [I 2025-08-05 08:48:26,995] Trial 2 finished with value: 0.6309966789701107 and parameters: {'d_model': 64, 'nhead': 4, 'num_layers': 3, 'dropout': 0.3422861609602237, 'lr': 0.0003061199003880646, 'batch_size': 128}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6483
# 📉 Epoch 2: Validation Loss = 0.6432
# 📉 Epoch 3: Validation Loss = 0.6281
# 📉 Epoch 4: Validation Loss = 0.6353
# 📉 Epoch 5: Validation Loss = 0.6118
# 📉 Epoch 6: Validation Loss = 0.6210
# 📉 Epoch 7: Validation Loss = 0.6164
# 📉 Epoch 8: Validation Loss = 0.6002
# 📉 Epoch 9: Validation Loss = 0.6202
# 📉 Epoch 10: Validation Loss = 0.6087
# 📉 Epoch 11: Validation Loss = 0.6190
# 📉 Epoch 12: Validation Loss = 0.5998
# 📉 Epoch 13: Validation Loss = 0.5929
# 📉 Epoch 14: Validation Loss = 0.5946
# 📉 Epoch 15: Validation Loss = 0.5855
# 📉 Epoch 16: Validation Loss = 0.5946
# 📉 Epoch 17: Validation Loss = 0.5873
# 📉 Epoch 18: Validation Loss = 0.5854
# 📉 Epoch 19: Validation Loss = 0.5859
# 📉 Epoch 20: Validation Loss = 0.5985
# ⛔ Early stopping triggered!
# [I 2025-08-05 08:49:04,493] Trial 3 finished with value: 0.6238282743844007 and parameters: {'d_model': 128, 'nhead': 4, 'num_layers': 1, 'dropout': 0.29826405547231727, 'lr': 0.001918631086645071, 'batch_size': 512}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6500
# 📉 Epoch 2: Validation Loss = 0.6454
# 📉 Epoch 3: Validation Loss = 0.6449
# 📉 Epoch 4: Validation Loss = 0.6423
# 📉 Epoch 5: Validation Loss = 0.6405
# 📉 Epoch 6: Validation Loss = 0.6253
# 📉 Epoch 7: Validation Loss = 0.6224
# 📉 Epoch 8: Validation Loss = 0.6171
# 📉 Epoch 9: Validation Loss = 0.6166
# 📉 Epoch 10: Validation Loss = 0.6147
# 📉 Epoch 11: Validation Loss = 0.6120
# 📉 Epoch 12: Validation Loss = 0.6082
# 📉 Epoch 13: Validation Loss = 0.6039
# 📉 Epoch 14: Validation Loss = 0.6000
# 📉 Epoch 15: Validation Loss = 0.6032
# 📉 Epoch 16: Validation Loss = 0.6010
# 📉 Epoch 17: Validation Loss = 0.5944
# 📉 Epoch 18: Validation Loss = 0.5955
# 📉 Epoch 19: Validation Loss = 0.5842
# 📉 Epoch 20: Validation Loss = 0.5875
# 📉 Epoch 21: Validation Loss = 0.5909
# 📉 Epoch 22: Validation Loss = 0.5867
# 📉 Epoch 23: Validation Loss = 0.5868
# 📉 Epoch 24: Validation Loss = 0.5750
# 📉 Epoch 25: Validation Loss = 0.5776
# 📉 Epoch 26: Validation Loss = 0.5742
# 📉 Epoch 27: Validation Loss = 0.5822
# 📉 Epoch 28: Validation Loss = 0.5713
# 📉 Epoch 29: Validation Loss = 0.5779
# 📉 Epoch 30: Validation Loss = 0.5725
# [I 2025-08-05 08:49:41,064] Trial 4 finished with value: 0.6375851408900357 and parameters: {'d_model': 64, 'nhead': 4, 'num_layers': 1, 'dropout': 0.4352624298088644, 'lr': 0.000902545094110882, 'batch_size': 512}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6511
# 📉 Epoch 2: Validation Loss = 0.6465
# 📉 Epoch 3: Validation Loss = 0.6434
# 📉 Epoch 4: Validation Loss = 0.6429
# 📉 Epoch 5: Validation Loss = 0.6337
# 📉 Epoch 6: Validation Loss = 0.6264
# 📉 Epoch 7: Validation Loss = 0.6257
# 📉 Epoch 8: Validation Loss = 0.6243
# 📉 Epoch 9: Validation Loss = 0.6149
# 📉 Epoch 10: Validation Loss = 0.6181
# 📉 Epoch 11: Validation Loss = 0.6110
# 📉 Epoch 12: Validation Loss = 0.6141
# 📉 Epoch 13: Validation Loss = 0.6188
# 📉 Epoch 14: Validation Loss = 0.6013
# 📉 Epoch 15: Validation Loss = 0.6028
# 📉 Epoch 16: Validation Loss = 0.6002
# 📉 Epoch 17: Validation Loss = 0.6018
# 📉 Epoch 18: Validation Loss = 0.5959
# 📉 Epoch 19: Validation Loss = 0.5984
# 📉 Epoch 20: Validation Loss = 0.5965
# 📉 Epoch 21: Validation Loss = 0.6054
# 📉 Epoch 22: Validation Loss = 0.5907
# 📉 Epoch 23: Validation Loss = 0.5958
# 📉 Epoch 24: Validation Loss = 0.5888
# 📉 Epoch 25: Validation Loss = 0.5906
# 📉 Epoch 26: Validation Loss = 0.5882
# 📉 Epoch 27: Validation Loss = 0.5816
# 📉 Epoch 28: Validation Loss = 0.5868
# 📉 Epoch 29: Validation Loss = 0.5885
# 📉 Epoch 30: Validation Loss = 0.5871
# [I 2025-08-05 08:51:29,058] Trial 5 finished with value: 0.6307513065614679 and parameters: {'d_model': 64, 'nhead': 8, 'num_layers': 3, 'dropout': 0.29414324379787704, 'lr': 0.00017623211588856574, 'batch_size': 256}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6504
# 📉 Epoch 2: Validation Loss = 0.6515
# 📉 Epoch 3: Validation Loss = 0.6427
# 📉 Epoch 4: Validation Loss = 0.6347
# 📉 Epoch 5: Validation Loss = 0.6277
# 📉 Epoch 6: Validation Loss = 0.6147
# 📉 Epoch 7: Validation Loss = 0.6289
# 📉 Epoch 8: Validation Loss = 0.6279
# 📉 Epoch 9: Validation Loss = 0.6294
# 📉 Epoch 10: Validation Loss = 0.6093
# 📉 Epoch 11: Validation Loss = 0.6277
# 📉 Epoch 12: Validation Loss = 0.6014
# 📉 Epoch 13: Validation Loss = 0.6214
# 📉 Epoch 14: Validation Loss = 0.6154
# 📉 Epoch 15: Validation Loss = 0.5999
# 📉 Epoch 16: Validation Loss = 0.5932
# 📉 Epoch 17: Validation Loss = 0.5877
# 📉 Epoch 18: Validation Loss = 0.6213
# 📉 Epoch 19: Validation Loss = 0.5870
# 📉 Epoch 20: Validation Loss = 0.6026
# 📉 Epoch 21: Validation Loss = 0.5929
# 📉 Epoch 22: Validation Loss = 0.5846
# 📉 Epoch 23: Validation Loss = 0.5700
# 📉 Epoch 24: Validation Loss = 0.5986
# 📉 Epoch 25: Validation Loss = 0.5985
# 📉 Epoch 26: Validation Loss = 0.5739
# 📉 Epoch 27: Validation Loss = 0.5821
# 📉 Epoch 28: Validation Loss = 0.5800
# ⛔ Early stopping triggered!
# [I 2025-08-05 08:54:09,898] Trial 6 finished with value: 0.6415774248607178 and parameters: {'d_model': 128, 'nhead': 8, 'num_layers': 3, 'dropout': 0.29931416795458354, 'lr': 0.0008490648361859691, 'batch_size': 256}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6461
# 📉 Epoch 2: Validation Loss = 0.6405
# 📉 Epoch 3: Validation Loss = 0.6488
# 📉 Epoch 4: Validation Loss = 0.6426
# 📉 Epoch 5: Validation Loss = 0.6472
# 📉 Epoch 6: Validation Loss = 0.6281
# 📉 Epoch 7: Validation Loss = 0.6507
# 📉 Epoch 8: Validation Loss = 0.6300
# 📉 Epoch 9: Validation Loss = 0.6213
# 📉 Epoch 10: Validation Loss = 0.6215
# 📉 Epoch 11: Validation Loss = 0.6168
# 📉 Epoch 12: Validation Loss = 0.6204
# 📉 Epoch 13: Validation Loss = 0.6260
# 📉 Epoch 14: Validation Loss = 0.6184
# 📉 Epoch 15: Validation Loss = 0.6157
# 📉 Epoch 16: Validation Loss = 0.6097
# 📉 Epoch 17: Validation Loss = 0.6118
# 📉 Epoch 18: Validation Loss = 0.6076
# 📉 Epoch 19: Validation Loss = 0.6079
# 📉 Epoch 20: Validation Loss = 0.6017
# 📉 Epoch 21: Validation Loss = 0.5998
# 📉 Epoch 22: Validation Loss = 0.6000
# 📉 Epoch 23: Validation Loss = 0.5980
# 📉 Epoch 24: Validation Loss = 0.5981
# 📉 Epoch 25: Validation Loss = 0.6004
# 📉 Epoch 26: Validation Loss = 0.5887
# 📉 Epoch 27: Validation Loss = 0.5968
# 📉 Epoch 28: Validation Loss = 0.5926
# 📉 Epoch 29: Validation Loss = 0.5945
# 📉 Epoch 30: Validation Loss = 0.6010
# [I 2025-08-05 08:55:26,793] Trial 7 finished with value: 0.6291520729692683 and parameters: {'d_model': 128, 'nhead': 2, 'num_layers': 1, 'dropout': 0.44315517946003746, 'lr': 0.0014076891372424493, 'batch_size': 128}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6797
# 📉 Epoch 2: Validation Loss = 0.6822
# 📉 Epoch 3: Validation Loss = 0.6694
# 📉 Epoch 4: Validation Loss = 0.6745
# 📉 Epoch 5: Validation Loss = 0.6749
# 📉 Epoch 6: Validation Loss = 0.6720
# 📉 Epoch 7: Validation Loss = 0.6743
# 📉 Epoch 8: Validation Loss = 0.6751
# ⛔ Early stopping triggered!
# [I 2025-08-05 08:55:55,836] Trial 8 finished with value: 0.5760231573545449 and parameters: {'d_model': 64, 'nhead': 4, 'num_layers': 3, 'dropout': 0.2934803171121071, 'lr': 0.004813102811991797, 'batch_size': 256}. Best is trial 1 with value: 0.6483240256123984.
# 📉 Epoch 1: Validation Loss = 0.6678
# 📉 Epoch 2: Validation Loss = 0.6548
# 📉 Epoch 3: Validation Loss = 0.6514
# 📉 Epoch 4: Validation Loss = 0.6482
# 📉 Epoch 5: Validation Loss = 0.6518
# 📉 Epoch 6: Validation Loss = 0.6471
# 📉 Epoch 7: Validation Loss = 0.6469
# 📉 Epoch 8: Validation Loss = 0.6471
# 📉 Epoch 9: Validation Loss = 0.6464
# 📉 Epoch 10: Validation Loss = 0.6484
# 📉 Epoch 11: Validation Loss = 0.6409
# 📉 Epoch 12: Validation Loss = 0.6478
# 📉 Epoch 13: Validation Loss = 0.6476
# 📉 Epoch 14: Validation Loss = 0.6338
# 📉 Epoch 15: Validation Loss = 0.6327
# 📉 Epoch 16: Validation Loss = 0.6432
# 📉 Epoch 17: Validation Loss = 0.6350
# 📉 Epoch 18: Validation Loss = 0.6321
# 📉 Epoch 19: Validation Loss = 0.6279
# 📉 Epoch 20: Validation Loss = 0.6472
# 📉 Epoch 21: Validation Loss = 0.6300
# 📉 Epoch 22: Validation Loss = 0.6299
# 📉 Epoch 23: Validation Loss = 0.6212
# 📉 Epoch 24: Validation Loss = 0.6241
# 📉 Epoch 25: Validation Loss = 0.6160
# 📉 Epoch 26: Validation Loss = 0.6149
# 📉 Epoch 27: Validation Loss = 0.6160
# 📉 Epoch 28: Validation Loss = 0.6142
# 📉 Epoch 29: Validation Loss = 0.6161
# 📉 Epoch 30: Validation Loss = 0.6100
# [I 2025-08-05 08:57:44,142] Trial 9 finished with value: 0.6180448754269803 and parameters: {'d_model': 64, 'nhead': 4, 'num_layers': 3, 'dropout': 0.48472705180639913, 'lr': 0.00014957911230115926, 'batch_size': 256}. Best is trial 1 with value: 0.6483240256123984.
# 🔧 Best Transformer Params: {'d_model': 32, 'nhead': 2, 'num_layers': 1, 'dropout': 0.24372847923584276, 'lr': 0.002500389542492971, 'batch_size': 128}
# 📉 Epoch 1: Validation Loss = 0.6586
# 📉 Epoch 2: Validation Loss = 0.6449
# 📉 Epoch 3: Validation Loss = 0.6284
# 📉 Epoch 4: Validation Loss = 0.6175
# 📉 Epoch 5: Validation Loss = 0.6040
# 📉 Epoch 6: Validation Loss = 0.6073
# 📉 Epoch 7: Validation Loss = 0.5969
# 📉 Epoch 8: Validation Loss = 0.5913
# 📉 Epoch 9: Validation Loss = 0.5825
# 📉 Epoch 10: Validation Loss = 0.5759
# 📉 Epoch 11: Validation Loss = 0.5638
# 📉 Epoch 12: Validation Loss = 0.5826
# 📉 Epoch 13: Validation Loss = 0.5618
# 📉 Epoch 14: Validation Loss = 0.5635
# 📉 Epoch 15: Validation Loss = 0.5544
# 📉 Epoch 16: Validation Loss = 0.5699
# 📉 Epoch 17: Validation Loss = 0.5617
# 📉 Epoch 18: Validation Loss = 0.5560
# 📉 Epoch 19: Validation Loss = 0.5870
# 📉 Epoch 20: Validation Loss = 0.5471
# 📉 Epoch 21: Validation Loss = 0.5510
# 📉 Epoch 22: Validation Loss = 0.5400
# 📉 Epoch 23: Validation Loss = 0.5371
# 📉 Epoch 24: Validation Loss = 0.5580
# 📉 Epoch 25: Validation Loss = 0.5372
# 📉 Epoch 26: Validation Loss = 0.5519
# 📉 Epoch 27: Validation Loss = 0.5256
# 📉 Epoch 28: Validation Loss = 0.5361
# 📉 Epoch 29: Validation Loss = 0.5308
# 📉 Epoch 30: Validation Loss = 0.5475
#
# 📊 최종 F1 Score: 0.6484 (Best Threshold = 0.4999999999999998)
#               precision    recall  f1-score   support
#
#       재직자(0)       0.67      0.59      0.63      2000
#       퇴사자(1)       0.63      0.70      0.67      2000
#
#     accuracy                           0.65      4000
#    macro avg       0.65      0.65      0.65      4000
# weighted avg       0.65      0.65      0.65      4000
