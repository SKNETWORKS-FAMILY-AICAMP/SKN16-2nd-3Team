# %%
# !pip install optuna --quiet

# %%
# 나눔고딕 폰트 설치 및 설정
# !apt-get update -qq
# !apt-get install fonts-nanum -qq
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt

# 폰트 설정
import matplotlib.font_manager as fm

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 📦 필요한 라이브러리
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, f1_score, roc_curve, auc
import optuna
import warnings
warnings.filterwarnings("ignore")

# 📌 데이터 로드 및 전처리
df = pd.read_csv('/content/employee_new3.csv')
df = df[df['Gender'] != 'Other']
df['Resigned'] = df['Resigned'].astype(int)
for col in df.select_dtypes(include='object').columns:
    df[col] = LabelEncoder().fit_transform(df[col])

X = df.drop(columns=['Resigned', 'Employee_ID', 'Hire_Date'], errors='ignore')
y = df['Resigned']

# ⚖️ 클래스 균형 맞춤 (오버샘플링 방식)
X_0 = X[y == 0].sample(n=10000, random_state=42)
y_0 = y[y == 0].sample(n=10000, random_state=42)
X_1 = X[y == 1]
y_1 = y[y == 1]
repeat_count = 10000 // len(X_1) + 1
X_1_sampled = pd.concat([X_1] * repeat_count)[:10000].reset_index(drop=True)
y_1_sampled = pd.concat([y_1] * repeat_count)[:10000].reset_index(drop=True)

X_balanced = pd.concat([X_0, X_1_sampled]).reset_index(drop=True)
y_balanced = pd.concat([y_0, y_1_sampled]).reset_index(drop=True)

X_balanced = X_balanced.fillna(X_balanced.mean(numeric_only=True))
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_balanced)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_balanced, test_size=0.2, stratify=y_balanced, random_state=42)

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)

# 🧠 AutoEncoder 기반 분류 모델
class AutoEncoderClassifier(nn.Module):
    def __init__(self, input_dim, encoding_dim, dropout_rate):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, encoding_dim),
            nn.ReLU(),
            nn.Dropout(dropout_rate)
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, input_dim),
            nn.ReLU()
        )
        self.classifier = nn.Sequential(
            nn.Linear(encoding_dim, 1)
        )

    def forward(self, x):
        encoded = self.encoder(x)
        reconstructed = self.decoder(encoded)  # reconstruction은 쓰지 않지만 구조상 존재
        out = self.classifier(encoded)
        return out

# ⏹️ EarlyStopping 클래스
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# 🔁 학습 함수
def train(model, loader, lr, epochs, val_data=None, use_earlystop=True):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()
    early_stopping = EarlyStopping(patience=5, min_delta=0.001) if use_earlystop else None

    model.train()
    for epoch in range(epochs):
        for xb, yb in loader:
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()

        if use_earlystop and val_data is not None:
            model.eval()
            with torch.no_grad():
                val_x, val_y = val_data
                val_pred = model(val_x)
                val_loss = criterion(val_pred, val_y).item()
                print(f"📉 Epoch {epoch+1}: Validation Loss = {val_loss:.4f}")
                early_stopping(val_loss)
                if early_stopping.early_stop:
                    print("⛔ Early stopping triggered!")
                    break
            model.train()

    model.eval()
    with torch.no_grad():
        probs = torch.sigmoid(model(X_test_tensor)).numpy().flatten()
    return probs

# 📊 평가 함수 (F1 기준 threshold 찾기)
def evaluate(y_true, probs):
    best_f1, best_th = 0, 0.5
    for th in np.arange(0.1, 0.9, 0.01):
        pred = (probs >= th).astype(int)
        f1_0 = f1_score(y_true, pred, pos_label=0)
        f1_1 = f1_score(y_true, pred, pos_label=1)
        avg = (f1_0 + f1_1) / 2
        if avg > best_f1:
            best_f1 = avg
            best_th = th
    final_pred = (probs >= best_th).astype(int)
    report = classification_report(y_true, final_pred, output_dict=True)
    return best_f1, best_th, report, final_pred

# 🎯 Optuna 튜닝 objective 함수
def objective(trial):
    encoding_dim = trial.suggest_int('encoding_dim', 16, 128)
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [128, 256, 512])
    epochs = 30

    model = AutoEncoderClassifier(X_train.shape[1], encoding_dim, dropout_rate)

    full_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_size = int(0.1 * len(full_dataset))
    train_size = len(full_dataset) - val_size
    train_ds, val_ds = random_split(full_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_x, val_y = val_ds[:][0], val_ds[:][1]

    probs = train(model, train_loader, lr, epochs, val_data=(val_x, val_y), use_earlystop=True)
    f1, _, _, _ = evaluate(y_test, probs)
    return f1

# 🧪 Optuna 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=10)

# ✅ 최적 모델 학습 및 평가
best_params = study.best_params
print("🔧 Best Params:", best_params)

best_model = AutoEncoderClassifier(X_train.shape[1], best_params['encoding_dim'], best_params['dropout_rate'])
full_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_size = int(0.1 * len(full_dataset))
train_size = len(full_dataset) - val_size
train_ds, val_ds = random_split(full_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))
train_loader = DataLoader(train_ds, batch_size=best_params['batch_size'], shuffle=True)
val_x, val_y = val_ds[:][0], val_ds[:][1]

probs = train(best_model, train_loader, best_params['lr'], epochs=30, val_data=(val_x, val_y), use_earlystop=True)
f1, best_th, report, preds = evaluate(y_test, probs)

print(f"\n📊 최종 F1 Score: {f1:.4f} (Best Threshold = {best_th})")
print(classification_report(y_test, preds, target_names=["재직자(0)", "퇴사자(1)"]))

# 📈 ROC Curve 시각화
fpr, tpr, _ = roc_curve(y_test, probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("📈 ROC Curve - AutoEncoderClassifier")
plt.legend()
plt.grid()
plt.show()
# Out:
# [I 2025-08-05 07:48:40,174] A new study created in memory with name: no-name-94f0686b-3f8d-4de6-a76c-704dcf7654ef
# 📉 Epoch 1: Validation Loss = 0.6528
# 📉 Epoch 2: Validation Loss = 0.6462
# 📉 Epoch 3: Validation Loss = 0.6439
# 📉 Epoch 4: Validation Loss = 0.6425
# 📉 Epoch 5: Validation Loss = 0.6412
# 📉 Epoch 6: Validation Loss = 0.6402
# 📉 Epoch 7: Validation Loss = 0.6384
# 📉 Epoch 8: Validation Loss = 0.6368
# 📉 Epoch 9: Validation Loss = 0.6366
# 📉 Epoch 10: Validation Loss = 0.6347
# 📉 Epoch 11: Validation Loss = 0.6343
# 📉 Epoch 12: Validation Loss = 0.6337
# 📉 Epoch 13: Validation Loss = 0.6317
# 📉 Epoch 14: Validation Loss = 0.6307
# 📉 Epoch 15: Validation Loss = 0.6289
# 📉 Epoch 16: Validation Loss = 0.6278
# 📉 Epoch 17: Validation Loss = 0.6261
# 📉 Epoch 18: Validation Loss = 0.6246
# 📉 Epoch 19: Validation Loss = 0.6226
# 📉 Epoch 20: Validation Loss = 0.6214
# 📉 Epoch 21: Validation Loss = 0.6191
# 📉 Epoch 22: Validation Loss = 0.6174
# 📉 Epoch 23: Validation Loss = 0.6162
# 📉 Epoch 24: Validation Loss = 0.6137
# 📉 Epoch 25: Validation Loss = 0.6117
# 📉 Epoch 26: Validation Loss = 0.6093
# 📉 Epoch 27: Validation Loss = 0.6071
# 📉 Epoch 28: Validation Loss = 0.6045
# 📉 Epoch 29: Validation Loss = 0.6033
# 📉 Epoch 30: Validation Loss = 0.6015
# [I 2025-08-05 07:48:56,852] Trial 0 finished with value: 0.6291199553538718 and parameters: {'encoding_dim': 80, 'dropout_rate': 0.38781908837237744, 'lr': 0.0009061880684050167, 'batch_size': 128}. Best is trial 0 with value: 0.6291199553538718.
# 📉 Epoch 1: Validation Loss = 0.6388
# 📉 Epoch 2: Validation Loss = 0.6245
# 📉 Epoch 3: Validation Loss = 0.6104
# 📉 Epoch 4: Validation Loss = 0.5945
# 📉 Epoch 5: Validation Loss = 0.5770
# 📉 Epoch 6: Validation Loss = 0.5665
# 📉 Epoch 7: Validation Loss = 0.5583
# 📉 Epoch 8: Validation Loss = 0.5609
# 📉 Epoch 9: Validation Loss = 0.5518
# 📉 Epoch 10: Validation Loss = 0.5511
# 📉 Epoch 11: Validation Loss = 0.5460
# 📉 Epoch 12: Validation Loss = 0.5387
# 📉 Epoch 13: Validation Loss = 0.5382
# 📉 Epoch 14: Validation Loss = 0.5324
# 📉 Epoch 15: Validation Loss = 0.5300
# 📉 Epoch 16: Validation Loss = 0.5275
# 📉 Epoch 17: Validation Loss = 0.5233
# 📉 Epoch 18: Validation Loss = 0.5216
# 📉 Epoch 19: Validation Loss = 0.5219
# 📉 Epoch 20: Validation Loss = 0.5198
# 📉 Epoch 21: Validation Loss = 0.5119
# 📉 Epoch 22: Validation Loss = 0.5202
# 📉 Epoch 23: Validation Loss = 0.5153
# 📉 Epoch 24: Validation Loss = 0.5092
# 📉 Epoch 25: Validation Loss = 0.5119
# 📉 Epoch 26: Validation Loss = 0.5133
# 📉 Epoch 27: Validation Loss = 0.5169
# 📉 Epoch 28: Validation Loss = 0.5095
# 📉 Epoch 29: Validation Loss = 0.5131
# ⛔ Early stopping triggered!
# [I 2025-08-05 07:49:05,536] Trial 1 finished with value: 0.6447052600587833 and parameters: {'encoding_dim': 96, 'dropout_rate': 0.27937315793717066, 'lr': 0.00939236014289022, 'batch_size': 128}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6686
# 📉 Epoch 2: Validation Loss = 0.6533
# 📉 Epoch 3: Validation Loss = 0.6472
# 📉 Epoch 4: Validation Loss = 0.6455
# 📉 Epoch 5: Validation Loss = 0.6441
# 📉 Epoch 6: Validation Loss = 0.6424
# 📉 Epoch 7: Validation Loss = 0.6417
# 📉 Epoch 8: Validation Loss = 0.6407
# 📉 Epoch 9: Validation Loss = 0.6405
# 📉 Epoch 10: Validation Loss = 0.6401
# 📉 Epoch 11: Validation Loss = 0.6390
# 📉 Epoch 12: Validation Loss = 0.6381
# 📉 Epoch 13: Validation Loss = 0.6375
# 📉 Epoch 14: Validation Loss = 0.6369
# 📉 Epoch 15: Validation Loss = 0.6355
# 📉 Epoch 16: Validation Loss = 0.6341
# 📉 Epoch 17: Validation Loss = 0.6330
# 📉 Epoch 18: Validation Loss = 0.6321
# 📉 Epoch 19: Validation Loss = 0.6308
# 📉 Epoch 20: Validation Loss = 0.6300
# 📉 Epoch 21: Validation Loss = 0.6293
# 📉 Epoch 22: Validation Loss = 0.6279
# 📉 Epoch 23: Validation Loss = 0.6269
# 📉 Epoch 24: Validation Loss = 0.6260
# 📉 Epoch 25: Validation Loss = 0.6243
# 📉 Epoch 26: Validation Loss = 0.6228
# 📉 Epoch 27: Validation Loss = 0.6217
# 📉 Epoch 28: Validation Loss = 0.6206
# 📉 Epoch 29: Validation Loss = 0.6200
# 📉 Epoch 30: Validation Loss = 0.6188
# [I 2025-08-05 07:49:12,246] Trial 2 finished with value: 0.6163804542454345 and parameters: {'encoding_dim': 81, 'dropout_rate': 0.35500844555226296, 'lr': 0.001244894784355024, 'batch_size': 512}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6870
# 📉 Epoch 2: Validation Loss = 0.6809
# 📉 Epoch 3: Validation Loss = 0.6757
# 📉 Epoch 4: Validation Loss = 0.6712
# 📉 Epoch 5: Validation Loss = 0.6673
# 📉 Epoch 6: Validation Loss = 0.6637
# 📉 Epoch 7: Validation Loss = 0.6605
# 📉 Epoch 8: Validation Loss = 0.6579
# 📉 Epoch 9: Validation Loss = 0.6555
# 📉 Epoch 10: Validation Loss = 0.6536
# 📉 Epoch 11: Validation Loss = 0.6519
# 📉 Epoch 12: Validation Loss = 0.6503
# 📉 Epoch 13: Validation Loss = 0.6491
# 📉 Epoch 14: Validation Loss = 0.6481
# 📉 Epoch 15: Validation Loss = 0.6473
# 📉 Epoch 16: Validation Loss = 0.6466
# 📉 Epoch 17: Validation Loss = 0.6459
# 📉 Epoch 18: Validation Loss = 0.6453
# 📉 Epoch 19: Validation Loss = 0.6447
# 📉 Epoch 20: Validation Loss = 0.6443
# 📉 Epoch 21: Validation Loss = 0.6438
# 📉 Epoch 22: Validation Loss = 0.6434
# 📉 Epoch 23: Validation Loss = 0.6431
# 📉 Epoch 24: Validation Loss = 0.6429
# 📉 Epoch 25: Validation Loss = 0.6427
# 📉 Epoch 26: Validation Loss = 0.6424
# 📉 Epoch 27: Validation Loss = 0.6422
# 📉 Epoch 28: Validation Loss = 0.6420
# 📉 Epoch 29: Validation Loss = 0.6420
# 📉 Epoch 30: Validation Loss = 0.6417
# ⛔ Early stopping triggered!
# [I 2025-08-05 07:49:17,482] Trial 3 finished with value: 0.6028793131292226 and parameters: {'encoding_dim': 32, 'dropout_rate': 0.24309146321879488, 'lr': 0.00033443835770374423, 'batch_size': 512}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6784
# 📉 Epoch 2: Validation Loss = 0.6630
# 📉 Epoch 3: Validation Loss = 0.6524
# 📉 Epoch 4: Validation Loss = 0.6478
# 📉 Epoch 5: Validation Loss = 0.6458
# 📉 Epoch 6: Validation Loss = 0.6448
# 📉 Epoch 7: Validation Loss = 0.6441
# 📉 Epoch 8: Validation Loss = 0.6438
# 📉 Epoch 9: Validation Loss = 0.6430
# 📉 Epoch 10: Validation Loss = 0.6427
# 📉 Epoch 11: Validation Loss = 0.6423
# 📉 Epoch 12: Validation Loss = 0.6418
# 📉 Epoch 13: Validation Loss = 0.6414
# 📉 Epoch 14: Validation Loss = 0.6410
# 📉 Epoch 15: Validation Loss = 0.6406
# 📉 Epoch 16: Validation Loss = 0.6398
# 📉 Epoch 17: Validation Loss = 0.6390
# 📉 Epoch 18: Validation Loss = 0.6387
# 📉 Epoch 19: Validation Loss = 0.6384
# 📉 Epoch 20: Validation Loss = 0.6377
# 📉 Epoch 21: Validation Loss = 0.6372
# 📉 Epoch 22: Validation Loss = 0.6364
# 📉 Epoch 23: Validation Loss = 0.6359
# 📉 Epoch 24: Validation Loss = 0.6352
# 📉 Epoch 25: Validation Loss = 0.6347
# 📉 Epoch 26: Validation Loss = 0.6345
# 📉 Epoch 27: Validation Loss = 0.6336
# 📉 Epoch 28: Validation Loss = 0.6332
# 📉 Epoch 29: Validation Loss = 0.6325
# 📉 Epoch 30: Validation Loss = 0.6318
# [I 2025-08-05 07:49:24,586] Trial 4 finished with value: 0.6146353299253609 and parameters: {'encoding_dim': 28, 'dropout_rate': 0.12957656608837348, 'lr': 0.0006902530912194481, 'batch_size': 256}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6465
# 📉 Epoch 2: Validation Loss = 0.6427
# 📉 Epoch 3: Validation Loss = 0.6412
# 📉 Epoch 4: Validation Loss = 0.6407
# 📉 Epoch 5: Validation Loss = 0.6400
# 📉 Epoch 6: Validation Loss = 0.6388
# 📉 Epoch 7: Validation Loss = 0.6376
# 📉 Epoch 8: Validation Loss = 0.6363
# 📉 Epoch 9: Validation Loss = 0.6349
# 📉 Epoch 10: Validation Loss = 0.6340
# 📉 Epoch 11: Validation Loss = 0.6324
# 📉 Epoch 12: Validation Loss = 0.6316
# 📉 Epoch 13: Validation Loss = 0.6292
# 📉 Epoch 14: Validation Loss = 0.6278
# 📉 Epoch 15: Validation Loss = 0.6280
# 📉 Epoch 16: Validation Loss = 0.6253
# 📉 Epoch 17: Validation Loss = 0.6238
# 📉 Epoch 18: Validation Loss = 0.6214
# 📉 Epoch 19: Validation Loss = 0.6207
# 📉 Epoch 20: Validation Loss = 0.6194
# 📉 Epoch 21: Validation Loss = 0.6178
# 📉 Epoch 22: Validation Loss = 0.6157
# 📉 Epoch 23: Validation Loss = 0.6144
# 📉 Epoch 24: Validation Loss = 0.6121
# 📉 Epoch 25: Validation Loss = 0.6114
# 📉 Epoch 26: Validation Loss = 0.6087
# 📉 Epoch 27: Validation Loss = 0.6068
# 📉 Epoch 28: Validation Loss = 0.6060
# 📉 Epoch 29: Validation Loss = 0.6045
# 📉 Epoch 30: Validation Loss = 0.6021
# [I 2025-08-05 07:49:33,442] Trial 5 finished with value: 0.6294981630328408 and parameters: {'encoding_dim': 109, 'dropout_rate': 0.31390559632198756, 'lr': 0.0009410657207467078, 'batch_size': 128}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6459
# 📉 Epoch 2: Validation Loss = 0.6416
# 📉 Epoch 3: Validation Loss = 0.6394
# 📉 Epoch 4: Validation Loss = 0.6379
# 📉 Epoch 5: Validation Loss = 0.6357
# 📉 Epoch 6: Validation Loss = 0.6338
# 📉 Epoch 7: Validation Loss = 0.6320
# 📉 Epoch 8: Validation Loss = 0.6325
# 📉 Epoch 9: Validation Loss = 0.6296
# 📉 Epoch 10: Validation Loss = 0.6284
# 📉 Epoch 11: Validation Loss = 0.6271
# 📉 Epoch 12: Validation Loss = 0.6272
# 📉 Epoch 13: Validation Loss = 0.6242
# 📉 Epoch 14: Validation Loss = 0.6214
# 📉 Epoch 15: Validation Loss = 0.6200
# 📉 Epoch 16: Validation Loss = 0.6188
# 📉 Epoch 17: Validation Loss = 0.6161
# 📉 Epoch 18: Validation Loss = 0.6145
# 📉 Epoch 19: Validation Loss = 0.6126
# 📉 Epoch 20: Validation Loss = 0.6113
# 📉 Epoch 21: Validation Loss = 0.6087
# 📉 Epoch 22: Validation Loss = 0.6069
# 📉 Epoch 23: Validation Loss = 0.6053
# 📉 Epoch 24: Validation Loss = 0.6024
# 📉 Epoch 25: Validation Loss = 0.6011
# 📉 Epoch 26: Validation Loss = 0.5996
# 📉 Epoch 27: Validation Loss = 0.5982
# 📉 Epoch 28: Validation Loss = 0.5968
# 📉 Epoch 29: Validation Loss = 0.5950
# 📉 Epoch 30: Validation Loss = 0.5940
# [I 2025-08-05 07:49:41,018] Trial 6 finished with value: 0.6336142374495937 and parameters: {'encoding_dim': 93, 'dropout_rate': 0.12207579848929534, 'lr': 0.0017756161546525183, 'batch_size': 256}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6772
# 📉 Epoch 2: Validation Loss = 0.6631
# 📉 Epoch 3: Validation Loss = 0.6541
# 📉 Epoch 4: Validation Loss = 0.6502
# 📉 Epoch 5: Validation Loss = 0.6480
# 📉 Epoch 6: Validation Loss = 0.6464
# 📉 Epoch 7: Validation Loss = 0.6458
# 📉 Epoch 8: Validation Loss = 0.6450
# 📉 Epoch 9: Validation Loss = 0.6446
# 📉 Epoch 10: Validation Loss = 0.6437
# 📉 Epoch 11: Validation Loss = 0.6438
# 📉 Epoch 12: Validation Loss = 0.6431
# 📉 Epoch 13: Validation Loss = 0.6426
# 📉 Epoch 14: Validation Loss = 0.6421
# 📉 Epoch 15: Validation Loss = 0.6411
# 📉 Epoch 16: Validation Loss = 0.6406
# 📉 Epoch 17: Validation Loss = 0.6402
# 📉 Epoch 18: Validation Loss = 0.6399
# 📉 Epoch 19: Validation Loss = 0.6394
# 📉 Epoch 20: Validation Loss = 0.6386
# 📉 Epoch 21: Validation Loss = 0.6379
# 📉 Epoch 22: Validation Loss = 0.6374
# 📉 Epoch 23: Validation Loss = 0.6371
# 📉 Epoch 24: Validation Loss = 0.6361
# 📉 Epoch 25: Validation Loss = 0.6358
# 📉 Epoch 26: Validation Loss = 0.6349
# 📉 Epoch 27: Validation Loss = 0.6341
# 📉 Epoch 28: Validation Loss = 0.6338
# 📉 Epoch 29: Validation Loss = 0.6332
# 📉 Epoch 30: Validation Loss = 0.6326
# [I 2025-08-05 07:49:46,464] Trial 7 finished with value: 0.6109999027499757 and parameters: {'encoding_dim': 61, 'dropout_rate': 0.10214188977074593, 'lr': 0.0008517267820831381, 'batch_size': 512}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6484
# 📉 Epoch 2: Validation Loss = 0.6436
# 📉 Epoch 3: Validation Loss = 0.6420
# 📉 Epoch 4: Validation Loss = 0.6403
# 📉 Epoch 5: Validation Loss = 0.6394
# 📉 Epoch 6: Validation Loss = 0.6387
# 📉 Epoch 7: Validation Loss = 0.6366
# 📉 Epoch 8: Validation Loss = 0.6340
# 📉 Epoch 9: Validation Loss = 0.6331
# 📉 Epoch 10: Validation Loss = 0.6315
# 📉 Epoch 11: Validation Loss = 0.6294
# 📉 Epoch 12: Validation Loss = 0.6267
# 📉 Epoch 13: Validation Loss = 0.6246
# 📉 Epoch 14: Validation Loss = 0.6231
# 📉 Epoch 15: Validation Loss = 0.6208
# 📉 Epoch 16: Validation Loss = 0.6186
# 📉 Epoch 17: Validation Loss = 0.6151
# 📉 Epoch 18: Validation Loss = 0.6130
# 📉 Epoch 19: Validation Loss = 0.6113
# 📉 Epoch 20: Validation Loss = 0.6087
# 📉 Epoch 21: Validation Loss = 0.6067
# 📉 Epoch 22: Validation Loss = 0.6036
# 📉 Epoch 23: Validation Loss = 0.6005
# 📉 Epoch 24: Validation Loss = 0.5989
# 📉 Epoch 25: Validation Loss = 0.5982
# 📉 Epoch 26: Validation Loss = 0.5949
# 📉 Epoch 27: Validation Loss = 0.5922
# 📉 Epoch 28: Validation Loss = 0.5903
# 📉 Epoch 29: Validation Loss = 0.5880
# 📉 Epoch 30: Validation Loss = 0.5866
# [I 2025-08-05 07:49:52,881] Trial 8 finished with value: 0.6330895964085946 and parameters: {'encoding_dim': 102, 'dropout_rate': 0.41817466181653506, 'lr': 0.002738542875892612, 'batch_size': 512}. Best is trial 1 with value: 0.6447052600587833.
# 📉 Epoch 1: Validation Loss = 0.6984
# 📉 Epoch 2: Validation Loss = 0.6928
# 📉 Epoch 3: Validation Loss = 0.6880
# 📉 Epoch 4: Validation Loss = 0.6840
# 📉 Epoch 5: Validation Loss = 0.6803
# 📉 Epoch 6: Validation Loss = 0.6771
# 📉 Epoch 7: Validation Loss = 0.6739
# 📉 Epoch 8: Validation Loss = 0.6709
# 📉 Epoch 9: Validation Loss = 0.6683
# 📉 Epoch 10: Validation Loss = 0.6658
# 📉 Epoch 11: Validation Loss = 0.6635
# 📉 Epoch 12: Validation Loss = 0.6612
# 📉 Epoch 13: Validation Loss = 0.6592
# 📉 Epoch 14: Validation Loss = 0.6574
# 📉 Epoch 15: Validation Loss = 0.6557
# 📉 Epoch 16: Validation Loss = 0.6543
# 📉 Epoch 17: Validation Loss = 0.6529
# 📉 Epoch 18: Validation Loss = 0.6517
# 📉 Epoch 19: Validation Loss = 0.6507
# 📉 Epoch 20: Validation Loss = 0.6497
# 📉 Epoch 21: Validation Loss = 0.6489
# 📉 Epoch 22: Validation Loss = 0.6481
# 📉 Epoch 23: Validation Loss = 0.6476
# 📉 Epoch 24: Validation Loss = 0.6471
# 📉 Epoch 25: Validation Loss = 0.6467
# 📉 Epoch 26: Validation Loss = 0.6463
# 📉 Epoch 27: Validation Loss = 0.6459
# 📉 Epoch 28: Validation Loss = 0.6455
# 📉 Epoch 29: Validation Loss = 0.6452
# 📉 Epoch 30: Validation Loss = 0.6449
# [I 2025-08-05 07:49:59,439] Trial 9 finished with value: 0.606391435438882 and parameters: {'encoding_dim': 43, 'dropout_rate': 0.46707743074321506, 'lr': 0.00017047886816231236, 'batch_size': 256}. Best is trial 1 with value: 0.6447052600587833.
# 🔧 Best Params: {'encoding_dim': 96, 'dropout_rate': 0.27937315793717066, 'lr': 0.00939236014289022, 'batch_size': 128}
# 📉 Epoch 1: Validation Loss = 0.6401
# 📉 Epoch 2: Validation Loss = 0.6310
# 📉 Epoch 3: Validation Loss = 0.6185
# 📉 Epoch 4: Validation Loss = 0.5952
# 📉 Epoch 5: Validation Loss = 0.5874
# 📉 Epoch 6: Validation Loss = 0.5787
# 📉 Epoch 7: Validation Loss = 0.5638
# 📉 Epoch 8: Validation Loss = 0.5577
# 📉 Epoch 9: Validation Loss = 0.5524
# 📉 Epoch 10: Validation Loss = 0.5415
# 📉 Epoch 11: Validation Loss = 0.5421
# 📉 Epoch 12: Validation Loss = 0.5454
# 📉 Epoch 13: Validation Loss = 0.5395
# 📉 Epoch 14: Validation Loss = 0.5271
# 📉 Epoch 15: Validation Loss = 0.5294
# 📉 Epoch 16: Validation Loss = 0.5243
# 📉 Epoch 17: Validation Loss = 0.5235
# 📉 Epoch 18: Validation Loss = 0.5177
# 📉 Epoch 19: Validation Loss = 0.5229
# 📉 Epoch 20: Validation Loss = 0.5197
# 📉 Epoch 21: Validation Loss = 0.5165
# 📉 Epoch 22: Validation Loss = 0.5186
# 📉 Epoch 23: Validation Loss = 0.5180
# 📉 Epoch 24: Validation Loss = 0.5137
# 📉 Epoch 25: Validation Loss = 0.5122
# 📉 Epoch 26: Validation Loss = 0.5162
# 📉 Epoch 27: Validation Loss = 0.5145
# 📉 Epoch 28: Validation Loss = 0.5154
# 📉 Epoch 29: Validation Loss = 0.5107
# 📉 Epoch 30: Validation Loss = 0.5144
#
# 📊 최종 F1 Score: 0.6618 (Best Threshold = 0.45999999999999985)
#               precision    recall  f1-score   support
#
#       재직자(0)       0.76      0.50      0.60      2000
#       퇴사자(1)       0.63      0.85      0.72      2000
#
#     accuracy                           0.67      4000
#    macro avg       0.70      0.67      0.66      4000
# weighted avg       0.70      0.67      0.66      4000
