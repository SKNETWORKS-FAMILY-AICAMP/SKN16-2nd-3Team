# %%
# !pip install optuna --quiet

# %%
# 나눔고딕 폰트 설치 및 설정
# !apt-get update -qq
# !apt-get install fonts-nanum -qq
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt

# 폰트 설정
import matplotlib.font_manager as fm

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, f1_score, roc_curve, auc
import optuna
import warnings
warnings.filterwarnings("ignore")

# 📌 데이터 로드 및 전처리
df = pd.read_csv('/content/employee_new3.csv')
df = df[df['Gender'] != 'Other']
df['Resigned'] = df['Resigned'].astype(int)
for col in df.select_dtypes(include='object').columns:
    df[col] = LabelEncoder().fit_transform(df[col])

X = df.drop(columns=['Resigned', 'Employee_ID', 'Hire_Date'], errors='ignore')
y = df['Resigned']

# 클래스 균형 맞춤
X_0 = X[y == 0].sample(n=10000, random_state=42)
y_0 = y[y == 0].sample(n=10000, random_state=42)
X_1 = X[y == 1]
y_1 = y[y == 1]
repeat_count = 10000 // len(X_1) + 1
X_1_sampled = pd.concat([X_1] * repeat_count)[:10000].reset_index(drop=True)
y_1_sampled = pd.concat([y_1] * repeat_count)[:10000].reset_index(drop=True)
X_balanced = pd.concat([X_0, X_1_sampled]).reset_index(drop=True)
y_balanced = pd.concat([y_0, y_1_sampled]).reset_index(drop=True)

X_balanced = X_balanced.fillna(X_balanced.mean(numeric_only=True))
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_balanced)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_balanced, test_size=0.2, stratify=y_balanced, random_state=42)

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)

# 🧠 DeepMLP 모델 정의 (Dropout + BatchNorm 포함)
class DeepMLP(nn.Module):
    def __init__(self, input_dim, hidden1, hidden2, dropout_rate=0.3):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden1, hidden2),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden2, 1)
        )

    def forward(self, x):
        return self.model(x)

# ⏹️ EarlyStopping 클래스
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# 🔁 학습 함수 (with early stopping)
def train(model, loader, lr, epochs, val_data=None, use_earlystop=True):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()
    early_stopping = EarlyStopping(patience=5, min_delta=0.001) if use_earlystop else None

    for epoch in range(epochs):
        model.train()
        for xb, yb in loader:
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()

        if use_earlystop and val_data is not None:
            model.eval()
            with torch.no_grad():
                val_x, val_y = val_data
                val_pred = model(val_x)
                val_loss = criterion(val_pred, val_y).item()
                print(f"📉 Epoch {epoch+1}: Validation Loss = {val_loss:.4f}")
                early_stopping(val_loss)
                if early_stopping.early_stop:
                    print("⛔ Early stopping triggered!")
                    break

    model.eval()
    with torch.no_grad():
        probs = torch.sigmoid(model(X_test_tensor)).numpy().flatten()
    return probs

# 📊 평가 함수
def evaluate(y_true, probs):
    best_f1, best_th = 0, 0.5
    for th in np.arange(0.1, 0.9, 0.01):
        pred = (probs >= th).astype(int)
        f1_0 = f1_score(y_true, pred, pos_label=0)
        f1_1 = f1_score(y_true, pred, pos_label=1)
        avg = (f1_0 + f1_1) / 2
        if avg > best_f1:
            best_f1 = avg
            best_th = th
    final_pred = (probs >= best_th).astype(int)
    report = classification_report(y_true, final_pred, output_dict=True)
    return best_f1, best_th, report, final_pred

# 🎯 Optuna 튜닝 objective 함수
def objective(trial):
    hidden1 = trial.suggest_int('hidden1', 64, 256)
    hidden2 = trial.suggest_int('hidden2', 32, 128)
    dropout = trial.suggest_float('dropout', 0.2, 0.5)
    lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [128, 256, 512])
    epochs = 30

    model = DeepMLP(X_train.shape[1], hidden1, hidden2, dropout_rate=dropout)

    full_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_size = int(0.1 * len(full_dataset))
    train_size = len(full_dataset) - val_size
    train_ds, val_ds = random_split(full_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    val_x, val_y = val_ds[:][0], val_ds[:][1]

    probs = train(model, train_loader, lr, epochs, val_data=(val_x, val_y), use_earlystop=True)
    f1, _, _, _ = evaluate(y_test, probs)
    return f1

# 🧪 Optuna 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=10)

# ✅ 최적 모델 학습 및 평가
best_params = study.best_params
print("🔧 Best Params:", best_params)

best_model = DeepMLP(X_train.shape[1], best_params['hidden1'], best_params['hidden2'], dropout_rate=best_params['dropout'])
full_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_size = int(0.1 * len(full_dataset))
train_size = len(full_dataset) - val_size
train_ds, val_ds = random_split(full_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(42))
train_loader = DataLoader(train_ds, batch_size=best_params['batch_size'], shuffle=True)
val_x, val_y = val_ds[:][0], val_ds[:][1]

probs = train(best_model, train_loader, best_params['lr'], epochs=30, val_data=(val_x, val_y), use_earlystop=True)
f1, best_th, report, preds = evaluate(y_test, probs)

print(f"\n📊 최종 F1 Score: {f1:.4f} (Best Threshold = {best_th})")
print(classification_report(y_test, preds, target_names=["재직자(0)", "퇴사자(1)"]))

# 📈 ROC Curve 시각화
fpr, tpr, _ = roc_curve(y_test, probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("📈 ROC Curve - 최적 DeepMLP 모델 (EarlyStopping + Dropout)")
plt.legend()
plt.grid()
plt.show()
# Out:
# [I 2025-08-05 07:44:11,855] A new study created in memory with name: no-name-ee1da16b-fc12-4e99-a345-5d285092d708
# 📉 Epoch 1: Validation Loss = 0.6764
# 📉 Epoch 2: Validation Loss = 0.6619
# 📉 Epoch 3: Validation Loss = 0.6548
# 📉 Epoch 4: Validation Loss = 0.6499
# 📉 Epoch 5: Validation Loss = 0.6472
# 📉 Epoch 6: Validation Loss = 0.6454
# 📉 Epoch 7: Validation Loss = 0.6439
# 📉 Epoch 8: Validation Loss = 0.6432
# 📉 Epoch 9: Validation Loss = 0.6420
# 📉 Epoch 10: Validation Loss = 0.6414
# 📉 Epoch 11: Validation Loss = 0.6411
# 📉 Epoch 12: Validation Loss = 0.6408
# 📉 Epoch 13: Validation Loss = 0.6399
# 📉 Epoch 14: Validation Loss = 0.6400
# 📉 Epoch 15: Validation Loss = 0.6402
# 📉 Epoch 16: Validation Loss = 0.6404
# 📉 Epoch 17: Validation Loss = 0.6401
# ⛔ Early stopping triggered!
# [I 2025-08-05 07:44:24,411] Trial 0 finished with value: 0.6075951279362117 and parameters: {'hidden1': 143, 'hidden2': 41, 'dropout': 0.4792669495513493, 'lr': 0.0001326240668454188, 'batch_size': 128}. Best is trial 0 with value: 0.6075951279362117.
# 📉 Epoch 1: Validation Loss = 0.6390
# 📉 Epoch 2: Validation Loss = 0.6283
# 📉 Epoch 3: Validation Loss = 0.6251
# 📉 Epoch 4: Validation Loss = 0.6159
# 📉 Epoch 5: Validation Loss = 0.6118
# 📉 Epoch 6: Validation Loss = 0.6053
# 📉 Epoch 7: Validation Loss = 0.6009
# 📉 Epoch 8: Validation Loss = 0.5917
# 📉 Epoch 9: Validation Loss = 0.5878
# 📉 Epoch 10: Validation Loss = 0.5772
# 📉 Epoch 11: Validation Loss = 0.5748
# 📉 Epoch 12: Validation Loss = 0.5692
# 📉 Epoch 13: Validation Loss = 0.5641
# 📉 Epoch 14: Validation Loss = 0.5666
# 📉 Epoch 15: Validation Loss = 0.5573
# 📉 Epoch 16: Validation Loss = 0.5525
# 📉 Epoch 17: Validation Loss = 0.5521
# 📉 Epoch 18: Validation Loss = 0.5475
# 📉 Epoch 19: Validation Loss = 0.5544
# 📉 Epoch 20: Validation Loss = 0.5495
# 📉 Epoch 21: Validation Loss = 0.5488
# 📉 Epoch 22: Validation Loss = 0.5424
# 📉 Epoch 23: Validation Loss = 0.5490
# 📉 Epoch 24: Validation Loss = 0.5408
# 📉 Epoch 25: Validation Loss = 0.5386
# 📉 Epoch 26: Validation Loss = 0.5399
# 📉 Epoch 27: Validation Loss = 0.5359
# 📉 Epoch 28: Validation Loss = 0.5398
# 📉 Epoch 29: Validation Loss = 0.5362
# 📉 Epoch 30: Validation Loss = 0.5346
# [I 2025-08-05 07:44:37,057] Trial 1 finished with value: 0.6517783006139013 and parameters: {'hidden1': 148, 'hidden2': 89, 'dropout': 0.24194971904847198, 'lr': 0.0023023941340164266, 'batch_size': 128}. Best is trial 1 with value: 0.6517783006139013.
# 📉 Epoch 1: Validation Loss = 0.6400
# 📉 Epoch 2: Validation Loss = 0.6372
# 📉 Epoch 3: Validation Loss = 0.6356
# 📉 Epoch 4: Validation Loss = 0.6340
# 📉 Epoch 5: Validation Loss = 0.6295
# 📉 Epoch 6: Validation Loss = 0.6267
# 📉 Epoch 7: Validation Loss = 0.6228
# 📉 Epoch 8: Validation Loss = 0.6205
# 📉 Epoch 9: Validation Loss = 0.6151
# 📉 Epoch 10: Validation Loss = 0.6112
# 📉 Epoch 11: Validation Loss = 0.6094
# 📉 Epoch 12: Validation Loss = 0.6066
# 📉 Epoch 13: Validation Loss = 0.5998
# 📉 Epoch 14: Validation Loss = 0.5950
# 📉 Epoch 15: Validation Loss = 0.5919
# 📉 Epoch 16: Validation Loss = 0.5874
# 📉 Epoch 17: Validation Loss = 0.5826
# 📉 Epoch 18: Validation Loss = 0.5759
# 📉 Epoch 19: Validation Loss = 0.5781
# 📉 Epoch 20: Validation Loss = 0.5697
# 📉 Epoch 21: Validation Loss = 0.5644
# 📉 Epoch 22: Validation Loss = 0.5592
# 📉 Epoch 23: Validation Loss = 0.5590
# 📉 Epoch 24: Validation Loss = 0.5571
# 📉 Epoch 25: Validation Loss = 0.5539
# 📉 Epoch 26: Validation Loss = 0.5513
# 📉 Epoch 27: Validation Loss = 0.5480
# 📉 Epoch 28: Validation Loss = 0.5434
# 📉 Epoch 29: Validation Loss = 0.5419
# 📉 Epoch 30: Validation Loss = 0.5376
# [I 2025-08-05 07:44:49,512] Trial 2 finished with value: 0.6537114603439398 and parameters: {'hidden1': 174, 'hidden2': 89, 'dropout': 0.4907642593510716, 'lr': 0.0020379497782479967, 'batch_size': 128}. Best is trial 2 with value: 0.6537114603439398.
# 📉 Epoch 1: Validation Loss = 0.6639
# 📉 Epoch 2: Validation Loss = 0.6500
# 📉 Epoch 3: Validation Loss = 0.6467
# 📉 Epoch 4: Validation Loss = 0.6441
# 📉 Epoch 5: Validation Loss = 0.6422
# 📉 Epoch 6: Validation Loss = 0.6412
# 📉 Epoch 7: Validation Loss = 0.6403
# 📉 Epoch 8: Validation Loss = 0.6393
# 📉 Epoch 9: Validation Loss = 0.6381
# 📉 Epoch 10: Validation Loss = 0.6378
# 📉 Epoch 11: Validation Loss = 0.6377
# 📉 Epoch 12: Validation Loss = 0.6373
# 📉 Epoch 13: Validation Loss = 0.6368
# 📉 Epoch 14: Validation Loss = 0.6359
# 📉 Epoch 15: Validation Loss = 0.6354
# 📉 Epoch 16: Validation Loss = 0.6353
# 📉 Epoch 17: Validation Loss = 0.6348
# 📉 Epoch 18: Validation Loss = 0.6347
# 📉 Epoch 19: Validation Loss = 0.6347
# 📉 Epoch 20: Validation Loss = 0.6345
# ⛔ Early stopping triggered!
# [I 2025-08-05 07:44:54,842] Trial 3 finished with value: 0.6093779117741553 and parameters: {'hidden1': 166, 'hidden2': 121, 'dropout': 0.27466141073695577, 'lr': 0.0001691665209560596, 'batch_size': 512}. Best is trial 2 with value: 0.6537114603439398.
# 📉 Epoch 1: Validation Loss = 0.6657
# 📉 Epoch 2: Validation Loss = 0.6546
# 📉 Epoch 3: Validation Loss = 0.6511
# 📉 Epoch 4: Validation Loss = 0.6493
# 📉 Epoch 5: Validation Loss = 0.6480
# 📉 Epoch 6: Validation Loss = 0.6468
# 📉 Epoch 7: Validation Loss = 0.6449
# 📉 Epoch 8: Validation Loss = 0.6444
# 📉 Epoch 9: Validation Loss = 0.6437
# 📉 Epoch 10: Validation Loss = 0.6430
# 📉 Epoch 11: Validation Loss = 0.6426
# 📉 Epoch 12: Validation Loss = 0.6417
# 📉 Epoch 13: Validation Loss = 0.6415
# 📉 Epoch 14: Validation Loss = 0.6406
# 📉 Epoch 15: Validation Loss = 0.6397
# 📉 Epoch 16: Validation Loss = 0.6391
# 📉 Epoch 17: Validation Loss = 0.6388
# 📉 Epoch 18: Validation Loss = 0.6378
# 📉 Epoch 19: Validation Loss = 0.6372
# 📉 Epoch 20: Validation Loss = 0.6367
# 📉 Epoch 21: Validation Loss = 0.6360
# 📉 Epoch 22: Validation Loss = 0.6356
# 📉 Epoch 23: Validation Loss = 0.6358
# 📉 Epoch 24: Validation Loss = 0.6356
# 📉 Epoch 25: Validation Loss = 0.6353
# 📉 Epoch 26: Validation Loss = 0.6348
# 📉 Epoch 27: Validation Loss = 0.6339
# 📉 Epoch 28: Validation Loss = 0.6334
# 📉 Epoch 29: Validation Loss = 0.6333
# 📉 Epoch 30: Validation Loss = 0.6328
# [I 2025-08-05 07:45:02,963] Trial 4 finished with value: 0.6125029464097704 and parameters: {'hidden1': 110, 'hidden2': 65, 'dropout': 0.2811309347038404, 'lr': 0.0002872990697165432, 'batch_size': 512}. Best is trial 2 with value: 0.6537114603439398.
# 📉 Epoch 1: Validation Loss = 0.6433
# 📉 Epoch 2: Validation Loss = 0.6399
# 📉 Epoch 3: Validation Loss = 0.6360
# 📉 Epoch 4: Validation Loss = 0.6351
# 📉 Epoch 5: Validation Loss = 0.6325
# 📉 Epoch 6: Validation Loss = 0.6316
# 📉 Epoch 7: Validation Loss = 0.6281
# 📉 Epoch 8: Validation Loss = 0.6252
# 📉 Epoch 9: Validation Loss = 0.6208
# 📉 Epoch 10: Validation Loss = 0.6185
# 📉 Epoch 11: Validation Loss = 0.6179
# 📉 Epoch 12: Validation Loss = 0.6140
# 📉 Epoch 13: Validation Loss = 0.6140
# 📉 Epoch 14: Validation Loss = 0.6102
# 📉 Epoch 15: Validation Loss = 0.6053
# 📉 Epoch 16: Validation Loss = 0.6055
# 📉 Epoch 17: Validation Loss = 0.6003
# 📉 Epoch 18: Validation Loss = 0.5975
# 📉 Epoch 19: Validation Loss = 0.5959
# 📉 Epoch 20: Validation Loss = 0.5932
# 📉 Epoch 21: Validation Loss = 0.5893
# 📉 Epoch 22: Validation Loss = 0.5873
# 📉 Epoch 23: Validation Loss = 0.5857
# 📉 Epoch 24: Validation Loss = 0.5811
# 📉 Epoch 25: Validation Loss = 0.5772
# 📉 Epoch 26: Validation Loss = 0.5753
# 📉 Epoch 27: Validation Loss = 0.5721
# 📉 Epoch 28: Validation Loss = 0.5756
# 📉 Epoch 29: Validation Loss = 0.5683
# 📉 Epoch 30: Validation Loss = 0.5692
# [I 2025-08-05 07:45:11,227] Trial 5 finished with value: 0.6429442100328177 and parameters: {'hidden1': 121, 'hidden2': 106, 'dropout': 0.35600195412779845, 'lr': 0.0015074779188429385, 'batch_size': 256}. Best is trial 2 with value: 0.6537114603439398.
# 📉 Epoch 1: Validation Loss = 0.6412
# 📉 Epoch 2: Validation Loss = 0.6299
# 📉 Epoch 3: Validation Loss = 0.6170
# 📉 Epoch 4: Validation Loss = 0.6074
# 📉 Epoch 5: Validation Loss = 0.5918
# 📉 Epoch 6: Validation Loss = 0.5874
# 📉 Epoch 7: Validation Loss = 0.5713
# 📉 Epoch 8: Validation Loss = 0.5628
# 📉 Epoch 9: Validation Loss = 0.5592
# 📉 Epoch 10: Validation Loss = 0.5521
# 📉 Epoch 11: Validation Loss = 0.5463
# 📉 Epoch 12: Validation Loss = 0.5449
# 📉 Epoch 13: Validation Loss = 0.5289
# 📉 Epoch 14: Validation Loss = 0.5333
# 📉 Epoch 15: Validation Loss = 0.5279
# 📉 Epoch 16: Validation Loss = 0.5287
# 📉 Epoch 17: Validation Loss = 0.5273
# 📉 Epoch 18: Validation Loss = 0.5201
# 📉 Epoch 19: Validation Loss = 0.5183
# 📉 Epoch 20: Validation Loss = 0.5136
# 📉 Epoch 21: Validation Loss = 0.5177
# 📉 Epoch 22: Validation Loss = 0.5181
# 📉 Epoch 23: Validation Loss = 0.5142
# 📉 Epoch 24: Validation Loss = 0.5177
# 📉 Epoch 25: Validation Loss = 0.5182
# ⛔ Early stopping triggered!
# [I 2025-08-05 07:45:19,723] Trial 6 finished with value: 0.6521657312677483 and parameters: {'hidden1': 146, 'hidden2': 124, 'dropout': 0.2656692583678264, 'lr': 0.007848434320238084, 'batch_size': 256}. Best is trial 2 with value: 0.6537114603439398.
# 📉 Epoch 1: Validation Loss = 0.6557
# 📉 Epoch 2: Validation Loss = 0.6457
# 📉 Epoch 3: Validation Loss = 0.6429
# 📉 Epoch 4: Validation Loss = 0.6407
# 📉 Epoch 5: Validation Loss = 0.6398
# 📉 Epoch 6: Validation Loss = 0.6381
# 📉 Epoch 7: Validation Loss = 0.6377
# 📉 Epoch 8: Validation Loss = 0.6363
# 📉 Epoch 9: Validation Loss = 0.6353
# 📉 Epoch 10: Validation Loss = 0.6348
# 📉 Epoch 11: Validation Loss = 0.6335
# 📉 Epoch 12: Validation Loss = 0.6331
# 📉 Epoch 13: Validation Loss = 0.6324
# 📉 Epoch 14: Validation Loss = 0.6319
# 📉 Epoch 15: Validation Loss = 0.6311
# 📉 Epoch 16: Validation Loss = 0.6307
# 📉 Epoch 17: Validation Loss = 0.6303
# 📉 Epoch 18: Validation Loss = 0.6293
# 📉 Epoch 19: Validation Loss = 0.6287
# 📉 Epoch 20: Validation Loss = 0.6283
# 📉 Epoch 21: Validation Loss = 0.6282
# 📉 Epoch 22: Validation Loss = 0.6282
# 📉 Epoch 23: Validation Loss = 0.6270
# 📉 Epoch 24: Validation Loss = 0.6263
# 📉 Epoch 25: Validation Loss = 0.6260
# 📉 Epoch 26: Validation Loss = 0.6256
# 📉 Epoch 27: Validation Loss = 0.6251
# 📉 Epoch 28: Validation Loss = 0.6257
# 📉 Epoch 29: Validation Loss = 0.6244
# 📉 Epoch 30: Validation Loss = 0.6243
# [I 2025-08-05 07:45:29,629] Trial 7 finished with value: 0.6207732778754982 and parameters: {'hidden1': 253, 'hidden2': 51, 'dropout': 0.22046276685034344, 'lr': 0.00014805263973099303, 'batch_size': 256}. Best is trial 2 with value: 0.6537114603439398.
# 📉 Epoch 1: Validation Loss = 0.6461
# 📉 Epoch 2: Validation Loss = 0.6410
# 📉 Epoch 3: Validation Loss = 0.6395
# 📉 Epoch 4: Validation Loss = 0.6381
# 📉 Epoch 5: Validation Loss = 0.6377
# 📉 Epoch 6: Validation Loss = 0.6360
# 📉 Epoch 7: Validation Loss = 0.6360
# 📉 Epoch 8: Validation Loss = 0.6354
# 📉 Epoch 9: Validation Loss = 0.6343
# 📉 Epoch 10: Validation Loss = 0.6330
# 📉 Epoch 11: Validation Loss = 0.6329
# 📉 Epoch 12: Validation Loss = 0.6320
# 📉 Epoch 13: Validation Loss = 0.6306
# 📉 Epoch 14: Validation Loss = 0.6301
# 📉 Epoch 15: Validation Loss = 0.6288
# 📉 Epoch 16: Validation Loss = 0.6290
# 📉 Epoch 17: Validation Loss = 0.6283
# 📉 Epoch 18: Validation Loss = 0.6264
# 📉 Epoch 19: Validation Loss = 0.6256
# 📉 Epoch 20: Validation Loss = 0.6257
# 📉 Epoch 21: Validation Loss = 0.6247
# 📉 Epoch 22: Validation Loss = 0.6247
# 📉 Epoch 23: Validation Loss = 0.6228
# 📉 Epoch 24: Validation Loss = 0.6221
# 📉 Epoch 25: Validation Loss = 0.6210
# 📉 Epoch 26: Validation Loss = 0.6217
# 📉 Epoch 27: Validation Loss = 0.6198
# 📉 Epoch 28: Validation Loss = 0.6196
# 📉 Epoch 29: Validation Loss = 0.6191
# 📉 Epoch 30: Validation Loss = 0.6185
# [I 2025-08-05 07:45:39,596] Trial 8 finished with value: 0.6229383349674966 and parameters: {'hidden1': 221, 'hidden2': 50, 'dropout': 0.292188349084896, 'lr': 0.0003122427900761286, 'batch_size': 256}. Best is trial 2 with value: 0.6537114603439398.
# 📉 Epoch 1: Validation Loss = 0.6482
# 📉 Epoch 2: Validation Loss = 0.6428
# 📉 Epoch 3: Validation Loss = 0.6405
# 📉 Epoch 4: Validation Loss = 0.6395
# 📉 Epoch 5: Validation Loss = 0.6388
# 📉 Epoch 6: Validation Loss = 0.6371
# 📉 Epoch 7: Validation Loss = 0.6364
# 📉 Epoch 8: Validation Loss = 0.6349
# 📉 Epoch 9: Validation Loss = 0.6337
# 📉 Epoch 10: Validation Loss = 0.6328
# 📉 Epoch 11: Validation Loss = 0.6330
# 📉 Epoch 12: Validation Loss = 0.6307
# 📉 Epoch 13: Validation Loss = 0.6306
# 📉 Epoch 14: Validation Loss = 0.6288
# 📉 Epoch 15: Validation Loss = 0.6264
# 📉 Epoch 16: Validation Loss = 0.6257
# 📉 Epoch 17: Validation Loss = 0.6250
# 📉 Epoch 18: Validation Loss = 0.6248
# 📉 Epoch 19: Validation Loss = 0.6237
# 📉 Epoch 20: Validation Loss = 0.6231
# 📉 Epoch 21: Validation Loss = 0.6214
# 📉 Epoch 22: Validation Loss = 0.6201
# 📉 Epoch 23: Validation Loss = 0.6193
# 📉 Epoch 24: Validation Loss = 0.6174
# 📉 Epoch 25: Validation Loss = 0.6171
# 📉 Epoch 26: Validation Loss = 0.6156
# 📉 Epoch 27: Validation Loss = 0.6132
# 📉 Epoch 28: Validation Loss = 0.6123
# 📉 Epoch 29: Validation Loss = 0.6115
# 📉 Epoch 30: Validation Loss = 0.6105
# [I 2025-08-05 07:45:46,000] Trial 9 finished with value: 0.620561629256966 and parameters: {'hidden1': 113, 'hidden2': 86, 'dropout': 0.39676957661111023, 'lr': 0.0010081060012929728, 'batch_size': 512}. Best is trial 2 with value: 0.6537114603439398.
# 🔧 Best Params: {'hidden1': 174, 'hidden2': 89, 'dropout': 0.4907642593510716, 'lr': 0.0020379497782479967, 'batch_size': 128}
# 📉 Epoch 1: Validation Loss = 0.6436
# 📉 Epoch 2: Validation Loss = 0.6388
# 📉 Epoch 3: Validation Loss = 0.6359
# 📉 Epoch 4: Validation Loss = 0.6363
# 📉 Epoch 5: Validation Loss = 0.6307
# 📉 Epoch 6: Validation Loss = 0.6269
# 📉 Epoch 7: Validation Loss = 0.6243
# 📉 Epoch 8: Validation Loss = 0.6170
# 📉 Epoch 9: Validation Loss = 0.6131
# 📉 Epoch 10: Validation Loss = 0.6128
# 📉 Epoch 11: Validation Loss = 0.6068
# 📉 Epoch 12: Validation Loss = 0.6033
# 📉 Epoch 13: Validation Loss = 0.5960
# 📉 Epoch 14: Validation Loss = 0.5912
# 📉 Epoch 15: Validation Loss = 0.5890
# 📉 Epoch 16: Validation Loss = 0.5814
# 📉 Epoch 17: Validation Loss = 0.5771
# 📉 Epoch 18: Validation Loss = 0.5732
# 📉 Epoch 19: Validation Loss = 0.5702
# 📉 Epoch 20: Validation Loss = 0.5683
# 📉 Epoch 21: Validation Loss = 0.5618
# 📉 Epoch 22: Validation Loss = 0.5609
# 📉 Epoch 23: Validation Loss = 0.5585
# 📉 Epoch 24: Validation Loss = 0.5548
# 📉 Epoch 25: Validation Loss = 0.5501
# 📉 Epoch 26: Validation Loss = 0.5497
# 📉 Epoch 27: Validation Loss = 0.5450
# 📉 Epoch 28: Validation Loss = 0.5403
# 📉 Epoch 29: Validation Loss = 0.5405
# 📉 Epoch 30: Validation Loss = 0.5345
#
# 📊 최종 F1 Score: 0.6496 (Best Threshold = 0.47999999999999976)
#               precision    recall  f1-score   support
#
#       재직자(0)       0.74      0.49      0.59      2000
#       퇴사자(1)       0.62      0.83      0.71      2000
#
#     accuracy                           0.66      4000
#    macro avg       0.68      0.66      0.65      4000
# weighted avg       0.68      0.66      0.65      4000
